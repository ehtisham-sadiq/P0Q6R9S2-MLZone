# %% [markdown]
# <h1 align="center">Backend using FastAPI</h1>

# %% [markdown]
# ## Outline of Notebook
#
# ### Introduction to FastAPI
# - Overview of FastAPI
# - Why choose FastAPI?
# - Setting up the development environment
#
# ### Basic Concepts
# - Understanding RESTful APIs
# - HTTP methods and status codes
# - Introduction to Pydantic for data validation
#
# ### Building Your First FastAPI Application
# - Creating a basic FastAPI app
# - Defining routes and handling requests
# - Running and testing the application
#
# ### Request Handling
# - Handling query parameters
# - Working with request bodies
# - Handling path parameters
# ### Response Handling
# - Returning JSON responses
# - Customizing response status codes
# - Handling errors and exceptions
# ### Authentication and Authorization
# - Implementing basic authentication
# - Securing routes with JWT tokens
# - Role-based access control
# ### Database Integration
# - Connecting FastAPI to a database
# - CRUD operations with SQLAlchemy
# - Data modeling with Pydantic
# ### Testing and Deployment
# - Writing unit tests for FastAPI applications
# - Containerizing FastAPI apps with Docker
# - Deploying FastAPI applications to cloud platforms
# ### Advanced Topics(Optional)
# - Background tasks and scheduling
# - WebSocket support in FastAPI
# - Integrating third-party APIs

# %%
from IPython.core.display import HTML

style = """
    <style>
        body {
            background-color: #f2fff2;
        }
        h1 {
            text-align: center;
            font-weight: bold;
            font-size: 36px;
            color: #4295F4;
            text-decoration: underline;
            padding-top: 15px;
        }
        
        h2 {
            text-align: left;
            font-weight: bold;
            font-size: 30px;
            color: #4A000A;
            text-decoration: underline;
            padding-top: 10px;
        }
        
        h3 {
            text-align: left;
            font-weight: bold;
            font-size: 30px;
            color: #f0081e;
            text-decoration: underline;
            padding-top: 5px;
        }

        
        p {
            text-align: center;
            font-size: 12 px;
            color: #0B9923;
        }
    </style>
"""

html_content = """
<h1>Hello</h1>
<p>Hello World</p>
<h2> Hello</h2>
<h3> World </h3>
"""

HTML(style + html_content)
# Out:
#     <style>
#         body {
#             background-color: #f2fff2;
#         }
#         h1 {
#             text-align: center;
#             font-weight: bold;
#             font-size: 36px;
#             color: #4295F4;
#             text-decoration: underline;
#             padding-top: 15px;
#         }
#
#         h2 {
#             text-align: left;
#             font-weight: bold;
#             font-size: 30px;
#             color: #4A000A;
#             text-decoration: underline;
#             padding-top: 10px;
#         }
#
#         h3 {
#             text-align: left;
#             font-weight: bold;
#             font-size: 30px;
#             color: #f0081e;
#             text-decoration: underline;
#             padding-top: 5px;
#         }
#
#
#         p {
#             text-align: center;
#             font-size: 12 px;
#             color: #0B9923;
#         }
#     </style>
#
# <h1>Hello</h1>
# <p>Hello World</p>
# <h2> Hello</h2>
# <h3> World </h3>
